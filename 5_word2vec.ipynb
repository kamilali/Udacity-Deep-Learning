# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.208573
# Nearest to most: ber, elegies, longsword, involving, lauderdale, herbalists, polarization, tack,
# Nearest to but: masada, grapefruit, synod, canonically, burbank, eco, patient, reader,
# Nearest to this: ems, dumfries, boltzmann, breezes, himachal, orosius, ingres, invalidate,
# Nearest to to: beersheba, edelman, pearls, vis, fiat, misgivings, burr, scorer,
# Nearest to called: longfellow, declarer, ghilzai, estranged, ordaining, macrostate, abjad, greatest,
# Nearest to states: lennox, niven, pylons, unexplored, forest, german, telepathy, numerous,
# Nearest to war: overgrown, nls, loser, montesquieu, volleyball, pasternak, sukkot, lying,
# Nearest to many: priest, stab, ensuring, deshima, normalize, galen, metabolite, ear,
# Nearest to no: provision, proposes, summarily, mbe, actively, koontz, robin, stewed,
# Nearest to people: fright, employer, pisa, teletext, getter, tunnel, reciprocating, soli,
# Nearest to zero: thurgood, acrobatics, unequivocal, tia, sunspots, smallholders, catabolism, tammy,
# Nearest to more: gettier, questioner, devotees, evidenced, avoided, eclectic, hannes, pressed,
# Nearest to five: cultivars, stanislaus, akm, cryptography, cells, aqueducts, locusts, bots,
# Nearest to s: belknap, miscarriages, distributist, sim, canoes, gkos, occultist, ssy,
# Nearest to on: tempering, trojan, airborne, wider, love, easily, mjd, antiaircraft,
# Nearest to and: yemeni, vincendeau, volvo, coup, evening, prix, body, disappear,
# Average loss at step 2000: 4.364888
# Average loss at step 4000: 3.864775
# Average loss at step 6000: 3.789596
# Average loss at step 8000: 3.686034
# Average loss at step 10000: 3.615460
# Nearest to most: contemporary, ber, more, fuego, behold, lows, lemon, hominy,
# Nearest to but: moustache, there, nocturnal, bequeathed, patient, galleon, unencumbered, campuses,
# Nearest to this: it, the, which, their, any, ems, aerials, that,
# Nearest to to: edelman, would, beans, schemes, memorization, pearls, homicide, frans,
# Nearest to called: bowman, ghilzai, longfellow, birthstone, intangible, greatest, wrestlers, swedish,
# Nearest to states: lennox, numerous, textbook, forest, unexplored, schneier, telepathy, flaherty,
# Nearest to war: nls, bengal, squadron, pasternak, epidemics, geotechnical, brood, ravenna,
# Nearest to many: some, several, gravitons, lambda, metabolite, shipwreck, ensuring, enters,
# Nearest to no: spongiform, jab, menai, provision, feeble, stewed, seditious, cervical,
# Nearest to people: teletext, fright, pakistanis, lithograph, employer, molten, pisa, heretofore,
# Nearest to zero: nine, eight, six, five, seven, three, four, two,
# Nearest to more: shipwrecked, most, quadra, pok, hal, method, marcius, kline,
# Nearest to five: six, eight, three, nine, seven, four, two, zero,
# Nearest to s: his, was, the, tailpiece, squared, and, petronas, medical,
# Nearest to on: in, by, emilio, chickie, rei, bug, throughout, from,
# Nearest to and: or, abitibi, imine, crandall, were, in, also, peep,
# Average loss at step 12000: 3.601770
# Average loss at step 14000: 3.571925
# Average loss at step 16000: 3.410708
# Average loss at step 18000: 3.454401
# Average loss at step 20000: 3.544001
# Nearest to most: some, more, contemporary, hominy, fuego, behold, stems, many,
# Nearest to but: however, and, that, is, there, though, which, auction,
# Nearest to this: it, which, the, semitone, icq, any, teleportation, he,
# Nearest to to: would, edelman, can, for, beans, will, not, homicide,
# Nearest to called: bowman, imagined, ghilzai, intangible, coursework, voip, see, oxidizer,
# Nearest to states: textbook, lennox, telepathy, husbands, stine, numerous, unexplored, heisenberg,
# Nearest to war: bengal, nls, geotechnical, pasternak, ravenna, epidemics, economically, montesquieu,
# Nearest to many: some, several, all, other, these, gravitons, such, shipwreck,
# Nearest to no: jab, seditious, it, spongiform, highly, cervical, hobbies, feeble,
# Nearest to people: fright, pakistanis, teletext, lejeune, victims, lithograph, those, molten,
# Nearest to zero: five, six, four, seven, three, eight, nine, two,
# Nearest to more: less, most, very, shipwrecked, enough, method, pasha, kline,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to s: petronas, stylistically, harnessing, reinforces, fiennes, medical, utilitarianism, tamazight,
# Nearest to on: in, upon, throughout, rei, emilio, threw, at, farkas,
# Nearest to and: or, but, for, in, which, ernesto, american, volvo,
# Average loss at step 22000: 3.502851
# Average loss at step 24000: 3.485616
# Average loss at step 26000: 3.483310
# Average loss at step 28000: 3.478498
# Average loss at step 30000: 3.504594
# Nearest to most: some, more, many, hominy, contemporary, trades, fuego, showered,
# Nearest to but: however, although, though, and, manageable, overseeing, uterine, should,
# Nearest to this: which, it, that, icq, what, the, any, there,
# Nearest to to: would, edelman, av, can, could, memorization, crank, will,
# Nearest to called: bowman, oxidizer, voip, imagined, wrestlers, used, held, rei,
# Nearest to states: textbook, lennox, kingdom, telepathy, husbands, unexplored, suffers, nations,
# Nearest to war: bengal, geotechnical, nls, geldof, pasternak, economically, spare, earp,
# Nearest to many: some, several, these, all, shipwreck, gravitons, most, scratches,
# Nearest to no: any, seditious, she, jab, paces, it, driving, spongiform,
# Nearest to people: fright, victims, those, teletext, pakistanis, bylaws, israel, laura,
# Nearest to zero: eight, five, seven, four, six, three, nine, two,
# Nearest to more: less, most, very, shipwrecked, rather, kline, greater, hesitate,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to s: his, petronas, bisected, cuba, assays, taya, louisbourg, divulge,
# Nearest to on: upon, in, throughout, at, from, into, delirium, with,
# Nearest to and: or, in, but, who, of, federal, disguising, depopulated,
# Average loss at step 32000: 3.497003
# Average loss at step 34000: 3.494032
# Average loss at step 36000: 3.457742
# Average loss at step 38000: 3.306412
# Average loss at step 40000: 3.426909
# Nearest to most: more, some, many, hominy, less, trades, deadlines, lang,
# Nearest to but: however, and, though, although, octavio, are, which, hurricane,
# Nearest to this: which, it, that, the, icq, any, itself, tocantins,
# Nearest to to: edelman, can, could, may, beersheba, will, tribune, must,
# Nearest to called: nutation, used, weights, imagined, voip, nsg, bowman, maternal,
# Nearest to states: kingdom, nations, telepathy, textbook, lennox, tactician, suffers, husbands,
# Nearest to war: bengal, geotechnical, spare, sumatran, battle, simulating, izzard, kaos,
# Nearest to many: some, several, these, most, gravitons, various, those, other,
# Nearest to no: any, seditious, she, paces, efficient, menai, driving, touring,
# Nearest to people: those, bylaws, scouting, teletext, victims, fright, women, kau,
# Nearest to zero: seven, five, nine, eight, six, four, three, two,
# Nearest to more: less, most, very, rather, greater, shipwrecked, enough, longer,
# Nearest to five: seven, six, four, three, eight, nine, zero, two,
# Nearest to s: his, grapes, fermions, ammianus, zombie, cuba, permanent, thirdly,
# Nearest to on: upon, at, with, dalit, throughout, from, in, about,
# Nearest to and: or, but, crandall, while, und, sus, in, however,
# Average loss at step 42000: 3.434374
# Average loss at step 44000: 3.454135
# Average loss at step 46000: 3.447718
# Average loss at step 48000: 3.362296
# Average loss at step 50000: 3.379587
# Nearest to most: more, many, less, some, trades, dice, largest, hominy,
# Nearest to but: however, though, and, although, while, when, there, who,
# Nearest to this: which, it, the, ignites, pencil, icq, coordinated, incidental,
# Nearest to to: would, could, can, must, through, should, gage, homicide,
# Nearest to called: used, nutation, conditional, crandall, referred, weights, ecommerce, maternal,
# Nearest to states: kingdom, nations, telepathy, textbook, alegre, suffers, tactician, lennox,
# Nearest to war: bengal, geotechnical, battle, simulating, spare, izzard, racehorse, sumatran,
# Nearest to many: some, several, these, various, other, most, both, gravitons,
# Nearest to no: any, seditious, roadster, she, paces, another, a, he,
# Nearest to people: children, men, teletext, women, victims, those, bylaws, edomites,
# Nearest to zero: seven, eight, five, six, nine, four, three, two,
# Nearest to more: less, most, very, rather, longer, larger, shipwrecked, eels,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to s: whose, his, divulge, and, taya, playmate, productions, your,
# Nearest to on: upon, in, throughout, bedroom, from, into, by, bug,
# Nearest to and: or, but, of, however, sequels, visuals, abitibi, while,
# Average loss at step 52000: 3.433915
# Average loss at step 54000: 3.427566
# Average loss at step 56000: 3.442100
# Average loss at step 58000: 3.400878
# Average loss at step 60000: 3.390978
# Nearest to most: more, some, many, use, less, trades, largest, all,
# Nearest to but: however, and, although, though, which, when, since, that,
# Nearest to this: which, it, that, there, the, itself, icq, heinous,
# Nearest to to: would, edelman, not, towards, must, for, memorization, will,
# Nearest to called: used, known, referred, smiley, louie, conditional, see, maternal,
# Nearest to states: nations, kingdom, alegre, telepathy, jurisdictions, countries, grounds, tactician,
# Nearest to war: bengal, battle, geotechnical, sumatran, castillian, breton, izzard, serotonin,
# Nearest to many: some, several, various, these, most, all, such, both,
# Nearest to no: any, determinate, little, pertwee, heterosexism, dnow, elisabeth, another,
# Nearest to people: women, men, those, victims, children, bylaws, jews, species,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to more: less, most, very, rather, longer, larger, shipwrecked, greater,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Nearest to s: taya, essene, garrison, inquest, your, whose, ammianus, grapes,
# Nearest to on: upon, emilio, through, dalit, in, bedroom, throughout, ifor,
# Nearest to and: or, but, including, reverses, although, visuals, ndebele, while,
# Average loss at step 62000: 3.241767
# Average loss at step 64000: 3.253506
# Average loss at step 66000: 3.405835
# Average loss at step 68000: 3.392700
# Average loss at step 70000: 3.359300
# Nearest to most: more, less, many, some, use, all, kew, especially,
# Nearest to but: however, although, and, though, really, that, macs, which,
# Nearest to this: which, it, the, there, that, any, another, ignites,
# Nearest to to: can, will, must, towards, may, would, might, edelman,
# Nearest to called: used, referred, but, known, maternal, see, roundabout, stresses,
# Nearest to states: kingdom, nations, telepathy, countries, reforms, suffers, jurisdictions, swings,
# Nearest to war: battle, bengal, apec, sumatran, geotechnical, castillian, izzard, putin,
# Nearest to many: some, several, various, these, all, most, numerous, both,
# Nearest to no: any, little, she, heterosexism, pertwee, stewed, elisabeth, deprivation,
# Nearest to people: women, men, children, those, victims, laura, shamanism, bylaws,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to more: less, most, very, rather, larger, extremely, enough, longer,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to s: your, permanent, whose, the, epidemiological, harnessing, enfield, adf,
# Nearest to on: upon, in, through, bedroom, emilio, about, within, throughout,
# Nearest to and: or, but, while, diefenbaker, penthouse, including, which, however,
# Average loss at step 72000: 3.377845
# Average loss at step 74000: 3.350370
# Average loss at step 76000: 3.311404
# Average loss at step 78000: 3.351860
# Average loss at step 80000: 3.377982
# Nearest to most: more, less, some, many, especially, particularly, use, all,
# Nearest to but: however, although, though, and, teletext, while, really, which,
# Nearest to this: which, it, the, bantu, another, there, what, freyr,
# Nearest to to: crank, franchisees, must, will, ary, would, kanji, can,
# Nearest to called: used, known, referred, maternal, fu, louie, named, correlatives,
# Nearest to states: kingdom, nations, countries, telepathy, taiko, forces, suffers, bracelet,
# Nearest to war: battle, bengal, ravenna, putin, sumatran, apec, enzyme, draco,
# Nearest to many: several, some, various, these, numerous, all, most, both,
# Nearest to no: little, roadster, conscience, determinate, any, she, heterosexism, compressor,
# Nearest to people: children, women, men, those, bylaws, someone, shamanism, others,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to more: less, very, most, larger, rather, extremely, shipwrecked, longer,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to s: whose, harnessing, naphtali, bisected, watering, your, nai, computability,
# Nearest to on: upon, in, through, at, delirium, during, from, throughout,
# Nearest to and: or, but, while, including, although, than, essene, lynn,
# Average loss at step 82000: 3.409711
# Average loss at step 84000: 3.410603
# Average loss at step 86000: 3.390720
# Average loss at step 88000: 3.352966
# Average loss at step 90000: 3.363751
# Nearest to most: more, some, many, less, use, especially, several, particularly,
# Nearest to but: however, although, though, and, while, really, which, dreadful,
# Nearest to this: it, which, any, the, congestion, some, itself, capuchin,
# Nearest to to: towards, would, will, smuggle, elsinore, crank, gage, should,
# Nearest to called: used, referred, known, maternal, named, see, fu, roundabout,
# Nearest to states: kingdom, nations, jurisdictions, countries, swings, telepathy, taiko, forces,
# Nearest to war: battle, putin, ravenna, bengal, syllable, castillian, sumatran, alarms,
# Nearest to many: some, several, various, these, numerous, most, all, those,
# Nearest to no: any, little, deprivation, only, conscience, efficient, compressor, dnow,
# Nearest to people: children, women, men, god, laura, shamanism, those, persons,
# Nearest to zero: eight, seven, five, six, nine, four, three, two,
# Nearest to more: less, very, most, rather, extremely, too, larger, greater,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Nearest to s: your, whose, harnessing, computability, divulge, his, essene, shotguns,
# Nearest to on: upon, through, under, babysitter, emilio, at, in, about,
# Nearest to and: or, but, including, while, however, crandall, of, by,
# Average loss at step 92000: 3.400897
# Average loss at step 94000: 3.251513
# Average loss at step 96000: 3.360224
# Average loss at step 98000: 3.245452
# Average loss at step 100000: 3.357513
# Nearest to most: more, less, especially, use, many, particularly, some, largest,
# Nearest to but: however, although, and, though, while, really, nevertheless, teletext,
# Nearest to this: which, it, the, that, ignites, what, he, itself,
# Nearest to to: will, towards, would, could, crank, must, should, shall,
# Nearest to called: referred, named, used, known, fu, maternal, see, tokens,
# Nearest to states: kingdom, nations, countries, jurisdictions, bracelet, swings, telepathy, taiko,
# Nearest to war: battle, bengal, kaos, castillian, ravenna, draco, sumatran, putin,
# Nearest to many: some, several, various, these, numerous, all, those, few,
# Nearest to no: any, little, deprivation, conscience, determinate, basra, menai, another,
# Nearest to people: children, women, persons, someone, individuals, those, god, men,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to more: less, most, very, larger, extremely, greater, rather, too,
# Nearest to five: seven, four, six, eight, three, nine, zero, two,
# Nearest to s: whose, his, your, my, subtext, harnessing, kangaroos, woodpecker,
# Nearest to on: upon, through, in, within, at, into, under, kettering,
# Nearest to and: or, but, although, however, visuals, while, when, tsim,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1,2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128
bag_window = 2
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset) # Look up embeddings for input
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1), labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    
    # Optimizer
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute similarity between batch examples and embeddings (use cosine distance)
    norm = tf.sqrt(tf.reduce_mean(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.313895
# Nearest to an: furlong, crust, piranha, severe, tiresias, yoda, cracks, atemi,
# Nearest to while: rasputin, decedent, magnetite, hogshead, companionship, labors, raman, shire,
# Nearest to not: injecting, clemente, khanum, corroborating, hartnell, mmorpg, perrin, yacht,
# Nearest to into: social, solemn, precision, genders, meets, fulda, caer, eminently,
# Nearest to of: innocent, hk, insights, damage, birch, touted, layout, hansen,
# Nearest to on: tapu, alkane, castillo, gnomes, segregationist, tron, bering, schellenberg,
# Nearest to will: lycos, barns, rifles, permutations, apache, letting, wand, sequencing,
# Nearest to many: ambulance, unicef, moxie, superb, lecompton, cameras, aardvark, paraffin,
# Nearest to had: differentiated, tuna, picard, arrests, marksmen, boney, millionth, traders,
# Nearest to over: mille, bile, invisibly, landforms, critically, tres, miscarriage, jeffries,
# Nearest to years: inferiority, unfulfilled, cruises, assembl, collared, supersymmetric, garrisons, xanadu,
# Nearest to american: tamarin, consecrated, more, skins, grassroots, incurred, statuary, melodies,
# Nearest to b: statutes, polemics, modem, carbonation, wong, several, fistful, saya,
# Nearest to if: zechs, linked, legal, wessel, earnest, ix, cro, divorces,
# Nearest to people: curd, piecemeal, bulk, lithuanian, palos, sloping, classifies, deviant,
# Nearest to i: leftists, indo, verdi, education, proclaim, nupedia, diger, consequent,
# Average loss at step 2000: 4.522184
# Average loss at step 4000: 3.876510
# Average loss at step 6000: 3.705786
# Average loss at step 8000: 3.691932
# Average loss at step 10000: 3.558821
# Nearest to an: the, a, this, another, sieve, grit, dis, knapp,
# Nearest to while: shire, however, stanley, but, lisp, vent, hex, haines,
# Nearest to not: what, dryer, it, anymore, diode, enlightened, fundamento, now,
# Nearest to into: from, maya, alford, hultsfred, with, xxxix, turnover, on,
# Nearest to of: for, duran, herein, hailstones, from, in, spaced, jumper,
# Nearest to on: in, from, upon, xps, commune, at, uploading, berlitz,
# Nearest to will: may, can, would, could, must, should, to, does,
# Nearest to many: some, several, all, both, other, various, papadopoulos, gpp,
# Nearest to had: has, have, having, was, became, would, marais, mikhail,
# Nearest to over: during, startling, alteration, coined, eicher, outage, chapultepec, anticipate,
# Nearest to years: pfaff, inferiority, bbb, animist, despair, assembl, people, quarto,
# Nearest to american: cryptographic, america, cadillac, inflected, trident, cornerback, fj, incurred,
# Nearest to b: d, suspends, r, kirwan, pemberton, statutes, befitting, guggenheim,
# Nearest to if: when, where, warranties, navigate, steelers, ayling, dfs, obeying,
# Nearest to people: forgetfulness, barricade, examples, afrique, years, doorway, embattled, llewellyn,
# Nearest to i: ii, tinged, ckel, partnership, pep, ammonia, russ, hermes,
# Average loss at step 12000: 3.441626
# Average loss at step 14000: 3.477198
# Average loss at step 16000: 3.395011
# Average loss at step 18000: 3.393086
# Average loss at step 20000: 3.376147
# Nearest to an: another, a, the, no, worries, ln, ricardo, artificially,
# Nearest to while: however, and, among, supplemented, with, longest, although, oi,
# Nearest to not: still, fundamento, publicized, mediation, now, retook, denning, catchment,
# Nearest to into: through, from, off, within, over, hultsfred, kirkwood, on,
# Nearest to of: following, during, rightist, including, at, detachments, for, meditations,
# Nearest to on: upon, in, hagen, through, at, commune, maxi, uploading,
# Nearest to will: would, could, must, can, may, should, cannot, might,
# Nearest to many: several, some, various, these, ossie, both, gpp, all,
# Nearest to had: has, have, having, was, were, impression, mouton, ipswich,
# Nearest to over: puzzles, through, before, glutamate, into, under, around, kiesinger,
# Nearest to years: days, months, times, year, pfaff, minutes, centuries, vrml,
# Nearest to american: america, international, lexicographer, inflected, marlon, nakano, reclaimed, azo,
# Nearest to b: idyllic, k, ploughing, kambojas, f, included, catacomb, anjiro,
# Nearest to if: when, though, steelers, before, where, since, after, variegated,
# Nearest to people: men, them, afrique, members, greenhouses, schubert, those, mnt,
# Nearest to i: ii, g, vauban, mail, accidentally, galactica, beats, we,
# Average loss at step 22000: 3.318490
# Average loss at step 24000: 3.114405
# Average loss at step 26000: 3.296175
# Average loss at step 28000: 3.236770
# Average loss at step 30000: 3.227394
# Nearest to an: another, the, a, no, artificially, chicken, ruiz, approx,
# Nearest to while: however, although, and, among, but, though, since, than,
# Nearest to not: still, now, insult, externalization, exempted, fundamento, it, interlaced,
# Nearest to into: through, within, from, off, inappropriately, chau, under, out,
# Nearest to of: in, roanoke, foreknowledge, delany, including, following, for, while,
# Nearest to on: upon, through, in, uploading, hagen, byrne, dassault, maxi,
# Nearest to will: would, must, may, can, could, should, cannot, might,
# Nearest to many: some, several, various, these, all, both, certain, thousands,
# Nearest to had: has, have, having, was, were, became, gave, could,
# Nearest to over: around, between, during, jehoiakim, before, under, after, relativistic,
# Nearest to years: months, days, decades, times, minutes, centuries, year, messages,
# Nearest to american: america, lexicographer, international, british, saline, einsatzgruppen, yellowstone, reclaimed,
# Nearest to b: c, d, idyllic, trier, replicating, single, three, explode,
# Nearest to if: when, since, though, because, furlong, vetoes, ellen, faceless,
# Nearest to people: those, men, openvms, others, inhabitants, protestants, members, them,
# Nearest to i: ii, ubangi, iii, vauban, we, vinland, g, delta,
# Average loss at step 32000: 3.228863
# Average loss at step 34000: 3.264781
# Average loss at step 36000: 3.196181
# Average loss at step 38000: 3.208916
# Average loss at step 40000: 3.102224
# Nearest to an: another, the, ruiz, artificially, no, knapp, sieve, a,
# Nearest to while: however, although, when, and, where, among, ochre, rulership,
# Nearest to not: now, still, usually, meandering, externalization, haphazard, fundamento, never,
# Nearest to into: through, within, under, across, from, around, down, off,
# Nearest to of: in, arrowhead, herein, including, votive, jour, contains, alexandrine,
# Nearest to on: upon, through, about, under, collie, commune, in, sourceforge,
# Nearest to will: would, may, could, must, can, should, might, cannot,
# Nearest to many: some, several, various, most, all, these, numerous, certain,
# Nearest to had: has, have, having, was, could, were, factually, germaine,
# Nearest to over: before, under, bubble, around, relativistic, within, shapiro, through,
# Nearest to years: days, months, decades, times, minutes, weeks, hours, centuries,
# Nearest to american: british, lexicographer, german, rulership, almagest, individuality, metabolic, america,
# Nearest to b: d, disappointments, bhangra, herbal, kendo, santana, salomon, statutes,
# Nearest to if: when, where, though, because, since, intervening, although, summand,
# Nearest to people: those, afrique, them, others, members, men, speakers, openvms,
# Nearest to i: g, we, ii, ubangi, iii, you, mail, constantius,
# Average loss at step 42000: 3.093083
# Average loss at step 44000: 3.143901
# Average loss at step 46000: 3.118871
# Average loss at step 48000: 2.981140
# Average loss at step 50000: 3.081391
# Nearest to an: another, the, ruiz, artificially, prickly, tyrannosaurus, pett, pupils,
# Nearest to while: although, and, among, including, despite, against, from, where,
# Nearest to not: now, never, still, rarely, usually, stains, insult, gregorian,
# Nearest to into: through, within, onto, towards, across, under, off, unnatural,
# Nearest to of: including, following, delany, before, concerning, for, include, in,
# Nearest to on: upon, through, in, uploading, maxi, against, miquelon, within,
# Nearest to will: would, can, could, must, should, may, might, cannot,
# Nearest to many: some, several, various, all, numerous, thousands, few, certain,
# Nearest to had: has, have, having, was, took, could, gave, saw,
# Nearest to over: across, before, through, when, relativistic, around, off, bubble,
# Nearest to years: days, months, decades, times, minutes, hours, centuries, weeks,
# Nearest to american: british, america, canadian, english, french, german, yellowstone, vlaamse,
# Nearest to b: c, d, q, binaries, vagueness, nationalization, sqrt, octal,
# Nearest to if: when, though, where, dfs, here, woes, copernican, detector,
# Nearest to people: others, those, members, scholars, christians, children, women, we,
# Nearest to i: ii, g, you, we, iii, usta, savers, mail,
# Average loss at step 52000: 3.069990
# Average loss at step 54000: 3.055303
# Average loss at step 56000: 2.964052
# Average loss at step 58000: 2.947159
# Average loss at step 60000: 3.022541
# Nearest to an: another, the, artificially, a, any, ruiz, tyrannosaurus, knapp,
# Nearest to while: although, and, however, among, against, cimmerian, quadriceps, mourners,
# Nearest to not: now, never, still, insult, jeanette, usually, sidelines, sampson,
# Nearest to into: through, within, from, under, onto, towards, in, down,
# Nearest to of: including, in, hailstones, gives, bw, against, towards, prototyping,
# Nearest to on: upon, in, onto, about, maxi, hagen, under, off,
# Nearest to will: would, must, can, may, should, could, might, cannot,
# Nearest to many: some, several, various, numerous, both, all, thousands, most,
# Nearest to had: has, have, having, was, were, is, saw, gave,
# Nearest to over: across, through, throughout, about, within, swabia, pessimism, at,
# Nearest to years: days, months, decades, minutes, year, hours, weeks, centuries,
# Nearest to american: british, english, canadian, australian, redman, french, abandon, lighted,
# Nearest to b: d, juden, f, pythagorean, porters, jeffersonian, adjunct, nx,
# Nearest to if: when, where, though, since, copernican, however, whether, because,
# Nearest to people: others, scholars, men, affectation, companies, women, players, those,
# Nearest to i: ii, mail, we, you, g, vauban, isambard, upholding,
# Average loss at step 62000: 3.044191
# Average loss at step 64000: 2.935670
# Average loss at step 66000: 2.950566
# Average loss at step 68000: 3.026881
# Average loss at step 70000: 3.024608
# Nearest to an: another, stabilized, zeeland, the, knapp, artificially, starve, no,
# Nearest to while: although, though, where, however, when, boomer, noel, but,
# Nearest to not: never, still, jeanette, now, almost, externalization, insult, already,
# Nearest to into: through, within, from, towards, across, onto, down, around,
# Nearest to of: following, concerning, in, bw, detachments, within, alexandrine, including,
# Nearest to on: upon, uploading, onto, maxi, hagen, toward, in, through,
# Nearest to will: would, could, can, must, should, cannot, might, may,
# Nearest to many: some, several, various, all, both, numerous, most, thousands,
# Nearest to had: has, have, having, saw, was, gives, contains, pharmacologic,
# Nearest to over: across, throughout, about, during, around, within, resuming, bubble,
# Nearest to years: months, decades, days, minutes, hours, weeks, centuries, year,
# Nearest to american: italian, british, america, canadian, australian, french, individual, independent,
# Nearest to b: d, c, royce, identifies, frac, poet, speer, binaries,
# Nearest to if: when, since, though, where, then, cronje, because, faceless,
# Nearest to people: others, men, those, students, scholars, inhabitants, person, speakers,
# Nearest to i: you, we, mail, g, ii, they, vauban, he,
# Average loss at step 72000: 2.860939
# Average loss at step 74000: 2.986323
# Average loss at step 76000: 2.919144
# Average loss at step 78000: 2.948950
# Average loss at step 80000: 2.966130
# Nearest to an: another, tyrannosaurus, any, recapture, stabilized, the, ruiz, starve,
# Nearest to while: although, and, including, unlike, though, against, when, among,
# Nearest to not: never, still, almost, already, publicized, insult, jeanette, exempted,
# Nearest to into: through, within, across, towards, onto, beyond, off, from,
# Nearest to of: following, in, including, concerning, while, ascertained, through, rightist,
# Nearest to on: upon, uploading, in, onto, through, off, bracelets, maxi,
# Nearest to will: would, might, should, must, may, can, could, cannot,
# Nearest to many: some, several, various, numerous, certain, both, all, thousands,
# Nearest to had: has, have, having, contains, was, includes, could, allows,
# Nearest to over: across, throughout, around, about, bubble, mik, during, through,
# Nearest to years: months, decades, days, hours, minutes, weeks, centuries, year,
# Nearest to american: america, british, canadian, italian, subclasses, australian, french, hamming,
# Nearest to b: d, q, c, frac, f, asl, complication, sittings,
# Nearest to if: when, though, whether, where, because, once, mau, here,
# Nearest to people: women, men, companies, persons, inhabitants, speakers, children, those,
# Nearest to i: you, we, g, mail, ii, they, vauban, alameda,
# Average loss at step 82000: 2.855880
# Average loss at step 84000: 2.932083
# Average loss at step 86000: 2.882867
# Average loss at step 88000: 2.641560
# Average loss at step 90000: 2.518765
# Nearest to an: another, any, the, starve, zeeland, a, b, quantized,
# Nearest to while: although, and, where, but, though, however, apostates, when,
# Nearest to not: never, exempted, still, rarely, aryeh, meandering, antiderivative, migrate,
# Nearest to into: through, across, within, onto, beyond, under, towards, down,
# Nearest to of: including, in, arrowhead, despite, etc, votive, juggling, among,
# Nearest to on: upon, onto, in, uploading, into, facing, xps, around,
# Nearest to will: would, must, should, could, can, might, may, cannot,
# Nearest to many: some, several, various, numerous, both, thousands, few, hundreds,
# Nearest to had: has, have, having, was, saw, contains, allows, includes,
# Nearest to over: through, across, about, throughout, bubble, during, beyond, within,
# Nearest to years: days, months, decades, hours, weeks, minutes, year, centuries,
# Nearest to american: canadian, english, british, australian, dir, baseball, references, bachelet,
# Nearest to b: d, cosmonauts, bose, carpets, valuation, medically, juden, non,
# Nearest to if: when, though, where, once, whether, then, cronje, hydroelectricity,
# Nearest to people: persons, children, men, students, workers, women, person, companies,
# Nearest to i: ii, iii, g, we, mail, usta, cholesterol, you,
# Average loss at step 92000: 2.786871
# Average loss at step 94000: 2.840310
# Average loss at step 96000: 2.898149
# Average loss at step 98000: 2.912421
# Average loss at step 100000: 2.745242
# Nearest to an: another, any, stabilized, tyrannosaurus, the, filius, entrails, spoofs,
# Nearest to while: although, though, however, and, apostates, where, when, but,
# Nearest to not: never, already, rarely, antiderivative, now, exempted, namibia, insult,
# Nearest to into: through, across, onto, down, within, around, under, on,
# Nearest to of: following, juggling, containing, sparingly, hailstones, concerning, for, epimorphism,
# Nearest to on: upon, uploading, through, onto, into, under, in, around,
# Nearest to will: would, should, must, can, might, could, cannot, may,
# Nearest to many: several, some, numerous, various, both, thousands, hundreds, all,
# Nearest to had: has, have, having, was, contains, could, includes, were,
# Nearest to over: across, through, around, about, beyond, throughout, within, away,
# Nearest to years: months, hours, decades, minutes, weeks, days, centuries, year,
# Nearest to american: australian, canadian, irish, italian, british, america, twa, french,
# Nearest to b: d, adjunct, q, pays, log, msg, db, f,
# Nearest to if: when, where, though, cronje, until, whether, thus, since,
# Nearest to people: jews, persons, citizens, students, person, soldiers, someone, individuals,
# Nearest to i: ii, we, g, iii, mail, you, vauban, isambard,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
