# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.648376
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.621365
# Minibatch accuracy: 43.8%
# Validation accuracy: 51.4%
# Minibatch loss at step 100: 0.993872
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.6%
# Minibatch loss at step 150: 0.383054
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.1%
# Minibatch loss at step 200: 0.731487
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 1.274179
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 0.350021
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 350: 0.575869
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 400: 0.198210
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 450: 0.697943
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 500: 0.716721
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 550: 0.804904
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.316767
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 650: 0.937336
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.818994
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.061012
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 800: 0.677632
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 850: 1.056997
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 900: 0.550513
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.665285
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.490281
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Test accuracy: 89.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    
    #Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    #Variables
    # Dimensions for conv weights are ==> patch_height * patch_width * # channels * depth
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=([depth])))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=([num_hidden])))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=([num_labels])))
    
    def model(data):
        # Dimensions for strides in conv layers are batch * patch_height * patch_weight * # channels
        # e.g. [1, 2, 2, 1]
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pool + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pool + layer2_biases)
        
        shape = hidden.get_shape().as_list()
        # batch_size * # total features <== dimensions of reshape
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
    
    # Training computation
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer
    # set arbitrary learning rate
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    # Predictions for train, validation, and test datasets
    train_predictions = tf.nn.softmax(logits)
    valid_predictions = tf.nn.softmax(model(tf_valid_dataset))
    test_predictions = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_predictions], feed_dict=feed_dict)
        
        # print results after every 50 steps
        if step % 50 == 0:
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_predictions.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_predictions.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.578502
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.4%
# Minibatch loss at step 50: 2.095940
# Minibatch accuracy: 18.8%
# Validation accuracy: 12.5%
# Minibatch loss at step 100: 1.132037
# Minibatch accuracy: 68.8%
# Validation accuracy: 60.1%
# Minibatch loss at step 150: 0.575631
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 200: 1.009418
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 250: 1.265356
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 300: 0.410024
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 350: 0.511104
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 400: 0.185245
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 450: 0.874217
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 500: 0.679845
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 550: 0.781638
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 600: 0.353096
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 650: 0.947170
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.811435
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 750: 0.049387
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 800: 0.627230
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 850: 0.823137
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 900: 0.542427
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.502131
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 1000: 0.349390
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Test accuracy: 90.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
keep_prob = 0.5

graph = tf.Graph()

with graph.as_default():
    
    # Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=([batch_size, image_size, image_size, num_channels]))
    tf_train_labels = tf.placeholder(tf.float32, shape=([batch_size, num_labels]))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Variables
    # Dimensions for conv weights are ==> patch_height * patch_width * # channels * depth
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=([depth])))
    layer3_weights = tf.Variable(tf.truncated_normal(
        [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=([num_hidden])))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=([num_labels])))
    
    def model(data):
        # Dimensions for strides in conv layers are batch * patch_height * patch_weight * # channels
        # e.g. [1, 2, 2, 1]
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pool + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pool + layer2_biases)
        
        shape = hidden.get_shape().as_list()
        # batch_size * # total features <== dimensions of reshape
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        hidden = tf.nn.dropout(hidden, keep_prob)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
    
    # Training computations
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    # Predictions for train, validation, and test datasets
    train_predictions = tf.nn.softmax(logits)
    valid_predictions = tf.nn.softmax(model(tf_valid_dataset))
    test_predictions = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_predictions], feed_dict=feed_dict)
        
        # print results after every 50 steps
        if step % 50 == 0:
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_predictions.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_predictions.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.284095
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 2.309104
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.321524
# Minibatch accuracy: 0.0%
# Validation accuracy: 11.9%
# Minibatch loss at step 150: 2.238084
# Minibatch accuracy: 25.0%
# Validation accuracy: 11.1%
# Minibatch loss at step 200: 1.927131
# Minibatch accuracy: 18.8%
# Validation accuracy: 27.4%
# Minibatch loss at step 250: 2.015536
# Minibatch accuracy: 31.2%
# Validation accuracy: 46.2%
# Minibatch loss at step 300: 1.096430
# Minibatch accuracy: 62.5%
# Validation accuracy: 50.7%
# Minibatch loss at step 350: 1.241962
# Minibatch accuracy: 50.0%
# Validation accuracy: 58.3%
# Minibatch loss at step 400: 0.758139
# Minibatch accuracy: 87.5%
# Validation accuracy: 58.5%
# Minibatch loss at step 450: 1.041650
# Minibatch accuracy: 68.8%
# Validation accuracy: 61.8%
# Minibatch loss at step 500: 1.282104
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.2%
# Minibatch loss at step 550: 1.223980
# Minibatch accuracy: 62.5%
# Validation accuracy: 70.0%
# Minibatch loss at step 600: 0.931109
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.4%
# Minibatch loss at step 650: 0.719348
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.7%
# Minibatch loss at step 700: 1.212624
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.1%
# Minibatch loss at step 750: 0.280607
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.7%
# Minibatch loss at step 800: 0.725359
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.5%
# Minibatch loss at step 850: 1.192930
# Minibatch accuracy: 62.5%
# Validation accuracy: 73.4%
# Minibatch loss at step 900: 0.831417
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.6%
# Minibatch loss at step 950: 0.987874
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.4%
# Minibatch loss at step 1000: 0.683668
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.2%
# Test accuracy: 81.7%

# %% [markdown]
# After applying dropout to the model, the accuracy decreased significantly. The model we implemented without dropout and using max pooling of stride 2 and kernel size 2 seemed to produce the greatest accuracy. Using that as a stepping stone, there might be room to investigate the use of valid padding rather than same padding. Also, utilizing learning rate decay may also help improve the accuracy.
#
# I propose the following model to test:
#    - Using a model with 2 convolutions and average pooling of stride 2 and kernel size 2
#    - Using valid padding

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    
    #Input data
    tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    #Variables
    # Dimensions for conv weights are ==> patch_height * patch_width * # channels * depth
    layer1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    layer2_biases = tf.Variable(tf.constant(1.0, shape=([depth])))
    new_size = ((image_size - patch_size + 1) / 2 - patch_size + 1) / 2
    layer3_weights = tf.Variable(tf.truncated_normal(
        [new_size * new_size * depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.constant(1.0, shape=([num_hidden])))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.constant(1.0, shape=([num_labels])))
    
    def model(data):
        # Dimensions for strides in conv layers are batch * patch_height * patch_weight * # channels
        # e.g. [1, 2, 2, 1]
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
        avg_pool = tf.nn.avg_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        hidden = tf.nn.relu(avg_pool + layer1_biases)
        
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='VALID')
        avg_pool = tf.nn.avg_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        hidden = tf.nn.relu(avg_pool + layer2_biases)
        
        shape = hidden.get_shape().as_list()
        # batch_size * # total features <== dimensions of reshape
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases
    
    # Training computation
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf_train_labels))
    
    # Optimizer
    # set arbitrary learning rate
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    
    # Predictions for train, validation, and test datasets
    train_predictions = tf.nn.softmax(logits)
    valid_predictions = tf.nn.softmax(model(tf_valid_dataset))
    test_predictions = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 20001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run([optimizer, loss, train_predictions], feed_dict=feed_dict)
        
        # print results after every 50 steps
        if step % 50 == 0:
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(valid_predictions.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_predictions.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.460052
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.826339
# Minibatch accuracy: 31.2%
# Validation accuracy: 50.8%
# Minibatch loss at step 100: 1.170673
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.9%
# Minibatch loss at step 150: 0.936268
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.2%
# Minibatch loss at step 200: 0.863309
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 250: 1.081261
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.6%
# Minibatch loss at step 300: 0.591220
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.6%
# Minibatch loss at step 350: 0.678739
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 400: 0.352687
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 450: 0.825565
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.2%
# Minibatch loss at step 500: 0.820468
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 550: 0.930508
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 600: 0.415201
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 650: 0.790288
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 700: 0.985075
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 750: 0.087569
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 800: 0.646764
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 850: 1.080445
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 900: 0.655537
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 950: 0.560638
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 1000: 0.457817
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 1050: 0.526172
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 1100: 0.762121
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 1150: 0.363871
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 1200: 0.970853
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 1250: 0.581476
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 1300: 0.267182
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 1350: 1.017926
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 1400: 0.333205
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 1450: 0.387317
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 1500: 0.639798
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1550: 0.601310
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1600: 0.887859
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 1650: 0.688567
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1700: 0.691377
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 1750: 0.435398
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1800: 0.660805
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 1850: 0.682877
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 1900: 0.367579
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 1950: 0.590371
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 2000: 0.113503
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 2050: 0.664921
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 2100: 0.248964
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 2150: 0.491138
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 2200: 0.361838
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 2250: 0.637478
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 2300: 0.617816
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 2350: 0.359502
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2400: 0.669580
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2450: 0.530258
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2500: 0.783955
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 2550: 0.646763
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 2600: 0.160217
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 2650: 0.352153
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 2700: 0.527709
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2750: 1.407655
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2800: 0.604786
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 2850: 0.143578
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2900: 0.351521
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 2950: 0.469172
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 3000: 0.625710
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 3050: 0.428689
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3100: 0.439386
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3150: 0.711578
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3200: 0.352344
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 3250: 0.367426
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 3300: 0.189083
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3350: 0.337215
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3400: 0.811803
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3450: 0.694845
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 3500: 0.275135
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3550: 0.175573
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 3600: 0.216076
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 3650: 0.791473
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 3700: 1.189811
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 3750: 0.838894
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3800: 0.070842
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 3850: 0.672958
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 3900: 0.584453
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 3950: 0.026763
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 4000: 0.456446
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 4050: 0.986095
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 4100: 0.439974
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4150: 1.108391
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 4200: 0.401622
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 4250: 0.571630
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 4300: 0.631212
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4350: 0.264838
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 4400: 1.237687
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 4450: 0.399163
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4500: 0.637227
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 4550: 0.335056
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 4600: 0.564620
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4650: 0.953477
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4700: 0.434167
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 4750: 0.752873
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4800: 0.443651
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 4850: 0.240175
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 4900: 0.047569
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 4950: 0.320267
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 5000: 0.946181
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 5050: 0.308478
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 5100: 0.242892
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 5150: 0.444909
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 5200: 0.269632
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 5250: 0.160534
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 5300: 0.244521
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 5350: 0.227101
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 5400: 0.479998
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 5450: 0.348380
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 5500: 0.642929
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 5550: 0.335561
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 5600: 0.296041
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 5650: 0.334947
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 5700: 0.438873
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 5750: 0.713967
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 5800: 0.279356
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 5850: 0.728473
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 5900: 0.814798
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 5950: 0.294853
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 6000: 0.150625
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 6050: 0.383766
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 6100: 0.815648
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 6150: 0.199197
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 6200: 1.263513
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6250: 0.869563
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 6300: 0.965531
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 6350: 0.199056
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 6400: 0.134184
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 6450: 0.344841
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6500: 0.740458
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 6550: 0.230327
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6600: 0.361950
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 6650: 1.612513
# Minibatch accuracy: 50.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 6700: 0.264100
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 6750: 0.380437
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 6800: 0.627683
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6850: 0.526012
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 6900: 0.386064
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 6950: 0.237787
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 7000: 0.851250
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 7050: 0.787595
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 7100: 0.459758
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 7150: 0.268098
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 7200: 0.498729
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 7250: 0.263579
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 7300: 0.600561
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 7350: 0.132494
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 7400: 0.018633
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 7450: 0.289431
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 7500: 0.215546
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 7550: 0.395380
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 7600: 0.506451
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 7650: 0.280789
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 7700: 0.092564
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 7750: 0.312671
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 7800: 0.185103
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 7850: 0.456708
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 7900: 0.140553
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 7950: 0.902437
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 8000: 0.384323
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 8050: 0.193003
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 8100: 0.452154
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 8150: 0.582598
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 8200: 0.371294
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 8250: 0.291000
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 8300: 0.260685
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 8350: 0.593844
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 8400: 0.396186
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 8450: 0.193061
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8500: 0.378409
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 8550: 0.418583
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 8600: 0.350307
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 8650: 0.438065
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 8700: 0.237238
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 8750: 0.144718
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 8800: 0.173175
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8850: 0.055206
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 8900: 0.430822
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 8950: 0.230313
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9000: 0.225273
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9050: 0.288997
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 9100: 0.333830
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 9150: 0.717766
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 9200: 0.173999
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9250: 0.786008
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 9300: 0.834765
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 9350: 0.228312
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 9400: 0.385215
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 9450: 0.372588
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9500: 0.209252
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 9550: 0.267848
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9600: 0.280625
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9650: 0.411104
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 9700: 0.075794
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 9750: 0.296132
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 9800: 0.447246
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 9850: 0.244539
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 9900: 0.787718
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 9950: 0.361224
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 10000: 0.093561
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 10050: 0.024187
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 10100: 0.371245
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 10150: 0.667880
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 10200: 0.165707
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 10250: 0.366059
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 10300: 0.129872
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 10350: 0.603478
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 10400: 0.409331
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 10450: 0.202546
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 10500: 0.235748
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 10550: 0.836417
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 10600: 0.614151
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 10650: 0.276362
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 10700: 0.029179
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 10750: 0.226602
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 10800: 0.384296
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 10850: 0.786831
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 10900: 0.329414
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 10950: 0.486839
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 11000: 0.097999
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 11050: 0.615588
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 11100: 0.189042
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 11150: 0.449892
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 11200: 0.189185
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 11250: 1.036342
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 11300: 0.374610
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 11350: 0.437831
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 11400: 0.245249
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 11450: 0.237817
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 11500: 0.303789
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 11550: 0.443413
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 11600: 0.328935
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 11650: 0.508309
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 11700: 1.023235
# Minibatch accuracy: 62.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 11750: 0.537009
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 11800: 0.112398
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 11850: 0.735122
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 11900: 0.433924
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 11950: 0.740144
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 12000: 0.495053
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 12050: 0.047389
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 12100: 0.387004
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 12150: 0.127168
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 12200: 0.347683
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 12250: 0.399215
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 12300: 0.368187
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 12350: 0.725285
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 12400: 0.029598
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 12450: 1.000704
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 12500: 0.641794
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 12550: 0.850005
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 12600: 0.427793
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 12650: 0.480132
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 12700: 0.287019
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 12750: 0.294013
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 12800: 0.185512
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 12850: 0.233026
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 12900: 0.240555
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 12950: 0.043923
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 13000: 0.323626
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 13050: 0.177428
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 13100: 0.183299
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 13150: 0.378228
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 13200: 0.393123
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 13250: 0.774740
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 13300: 0.261401
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 13350: 0.119295
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 13400: 0.598163
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 13450: 0.268652
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 13500: 0.243003
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 13550: 0.393419
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 13600: 0.288635
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 13650: 0.470298
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 13700: 0.246978
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 13750: 0.749718
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 13800: 0.025338
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 13850: 0.178233
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 13900: 0.168128
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 13950: 0.383424
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 14000: 0.110274
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 14050: 0.321026
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 14100: 0.611211
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 14150: 0.309900
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 14200: 0.128779
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 14250: 0.276853
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 14300: 0.325438
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 14350: 0.195673
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 14400: 0.331695
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 14450: 0.037418
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 14500: 0.437139
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 14550: 0.370692
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 14600: 0.042396
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 14650: 0.577715
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 14700: 0.260769
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 14750: 0.278150
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 14800: 0.453937
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 14850: 0.404645
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 14900: 0.254198
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 14950: 0.512888
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 15000: 0.228926
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 15050: 0.906672
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 15100: 0.158173
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 15150: 0.321454
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 15200: 0.069767
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 15250: 0.545372
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 15300: 0.168872
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 15350: 0.121137
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 15400: 0.758748
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 15450: 0.713781
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 15500: 0.108312
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 15550: 0.229905
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 15600: 0.417516
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 15650: 0.294031
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 15700: 0.248848
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 15750: 0.228399
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 15800: 0.145840
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 15850: 0.382644
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 15900: 0.726134
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 15950: 0.187599
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 16000: 1.145768
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 16050: 0.097663
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 16100: 0.179396
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 16150: 0.115900
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 16200: 0.335740
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 16250: 0.209201
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 16300: 0.763183
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 16350: 0.479186
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 16400: 0.648380
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 16450: 0.603368
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 16500: 0.016946
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 16550: 0.653820
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 16600: 0.352904
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 16650: 0.621691
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 16700: 0.375469
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 16750: 0.402433
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 16800: 0.792900
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.5%
# Minibatch loss at step 16850: 0.555293
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 16900: 0.943233
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 16950: 0.186510
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 17000: 0.153783
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 17050: 0.340857
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 17100: 0.333609
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 17150: 0.252943
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 17200: 0.259687
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 17250: 0.435599
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 17300: 0.188166
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 17350: 0.236745
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 17400: 0.575670
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 17450: 0.252040
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 17500: 0.422103
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 17550: 0.582003
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 17600: 0.519173
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 17650: 0.170141
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 17700: 0.563822
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.7%
# Minibatch loss at step 17750: 0.275898
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 17800: 0.512073
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 17850: 0.426206
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 17900: 0.388987
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 17950: 0.438410
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 18000: 0.400969
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 18050: 0.481948
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 18100: 0.602974
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Minibatch loss at step 18150: 0.174620
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 18200: 0.539469
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 18250: 0.624055
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 18300: 0.195966
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 18350: 0.252418
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 18400: 0.625089
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 18450: 0.255877
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 18500: 0.319082
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 18550: 0.556030
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 18600: 0.051437
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 18650: 0.316890
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 18700: 0.305419
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 18750: 0.751037
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 18800: 0.353434
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.7%
# Minibatch loss at step 18850: 0.397060
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.0%
# Minibatch loss at step 18900: 0.063911
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 18950: 0.120015
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 19000: 0.372639
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 19050: 0.075067
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.2%
# Minibatch loss at step 19100: 0.012068
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 19150: 0.515434
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 19200: 0.311464
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 19250: 0.668862
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 19300: 0.143772
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 19350: 0.217238
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 19400: 0.521601
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 19450: 0.388536
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 19500: 0.368755
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Minibatch loss at step 19550: 0.255902
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 19600: 0.406993
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 19650: 0.352407
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 19700: 0.150788
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 19750: 0.722836
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 19800: 0.334193
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Minibatch loss at step 19850: 0.118862
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 19900: 0.095681
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.8%
# Minibatch loss at step 19950: 0.543382
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 20000: 0.403263
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Test accuracy: 94.7%

# %% [markdown]
# The accuracy improved greatly. We can probably eek out more improvements by fine tuning the learning rate through implementing learning rate decay and maybe adding more layers. For now, it seems as though this newly proposed model has provided sufficient accuracy through using convolutions.
